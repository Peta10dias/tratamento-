# %%
import numpy as np
from datetime import datetime, timedelta
import pandas as pd 
df = pd.read_excel('Data_Frame.xlsx')

df
# Out:
#    RAZÃO SOCIAL    Data 01    Data 02    Data 03    Data 04    Data 05  \
# 0     Empresa A 2000-10-01 2000-12-01 2001-01-01 2001-04-01 2001-05-01
# 1    Empresa B  2000-10-02 2000-12-02 2001-01-02 2001-04-02 2001-05-02
# 2     Empresa C 2000-10-03 2000-12-03 2001-01-03 2001-04-03 2001-05-03
# 3     Empresa D 2000-10-04 2000-12-04 2001-01-04 2001-04-04 2001-05-04
# 4     Empresa E 2000-10-05 2000-12-05 2001-01-05 2001-04-05 2001-05-05
# 5    Empresa F  2000-10-06 2000-12-06 2001-01-06 2001-04-06 2001-05-06
# 6     Empresa G 2000-10-07 2000-12-07 2001-01-07 2001-04-07 2001-05-07
# 7     Empresa H 2000-10-08 2000-12-08 2001-01-08 2001-04-08 2001-05-08
# 8     Empresa I 2000-10-09 2000-12-09 2001-01-09 2001-04-09 2001-05-09
# 9     Empresa J 2000-10-10 2000-12-10 2001-01-10 2001-04-10 2001-05-10
# 10    Empresa K 2000-10-11 2000-12-11 2001-01-11 2001-04-11 2001-05-11
#
#       Data 06    Data 07    Data 08    Data 09    Data 10
# ...

# %%
etapas = ['Etapa 1',
         'Etapa 2',
         'Etapa 3',
          'Etapa 4',
          'Etapa 5',
          'Etapa 6',
          'Etapa 7',
          'Etapa 8',
          'Etapa 9']

# %%
novo_df = pd.DataFrame(columns=['RAZÃO SOCIAL', 'Etapa'])

# Iterar sobre as empresas no dataframe e adicionar as etapas correspondentes ao novo dataframe
for empresa in df['RAZÃO SOCIAL']:
    for etapa in etapas:
        novo_df = novo_df.append({'RAZÃO SOCIAL': empresa, 'Etapa': etapa}, ignore_index=True)

# Exibir o novo dataframe resultante
novo_df
# Out:
# C:\Users\estcgfd\AppData\Local\Temp\ipykernel_11092\183900122.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   novo_df = novo_df.append({'RAZÃO SOCIAL': empresa, 'Etapa': etapa}, ignore_index=True)
# C:\Users\estcgfd\AppData\Local\Temp\ipykernel_11092\183900122.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   novo_df = novo_df.append({'RAZÃO SOCIAL': empresa, 'Etapa': etapa}, ignore_index=True)
# C:\Users\estcgfd\AppData\Local\Temp\ipykernel_11092\183900122.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   novo_df = novo_df.append({'RAZÃO SOCIAL': empresa, 'Etapa': etapa}, ignore_index=True)
# ...

# %%
#data inicial 
# Filtrar df1 para as linhas em que etapas é igual a "fase 1"
df1_fase1 = novo_df[novo_df['Etapa'] == 'Etapa 1']
df1_fase2 = novo_df[novo_df['Etapa'] == 'Etapa 2']
df1_fase3 = novo_df[novo_df['Etapa'] == 'Etapa 3']
df1_fase4 = novo_df[novo_df['Etapa'] == 'Etapa 4']
df1_fase5 = novo_df[novo_df['Etapa'] == 'Etapa 5']
df1_fase6 = novo_df[novo_df['Etapa'] == 'Etapa 6']
df1_fase7 = novo_df[novo_df['Etapa'] == 'Etapa 7']
df1_fase8 = novo_df[novo_df['Etapa'] == 'Etapa 8']
df1_fase9 = novo_df[novo_df['Etapa'] == 'Etapa 9']

# Criar uma nova coluna 'data_inicial' em novo_df
novo_df['data_inicial'] = None

# Preencher a coluna 'data_inicial' em novo_df com as informações correspondentes em df2
for index, row in df1_fase1.iterrows():
    empresa = row['RAZÃO SOCIAL']
    if empresa in df['RAZÃO SOCIAL'].values:
        data_oficial = df.loc[df['RAZÃO SOCIAL'] == empresa, 'Data 01'].values[0]
        novo_df.at[index, 'data_inicial'] = data_oficial

for index, row in df1_fase2.iterrows():
    empresa = row['RAZÃO SOCIAL']
    if empresa in df['RAZÃO SOCIAL'].values:
        data_oficial2 = df.loc[df['RAZÃO SOCIAL'] == empresa, 'Data 02'].values[0]
        novo_df.at[index, 'data_inicial'] = data_oficial2
        
for index, row in df1_fase3.iterrows():
    empresa = row['RAZÃO SOCIAL']
    if empresa in df['RAZÃO SOCIAL'].values:
        data_oficial3 = df.loc[df['RAZÃO SOCIAL'] == empresa, 'Data 03'].values[0]
        novo_df.at[index, 'data_inicial'] = data_oficial3
        
for index, row in df1_fase4.iterrows():
    empresa = row['RAZÃO SOCIAL']
    if empresa in df['RAZÃO SOCIAL'].values:
        data_oficial4 = df.loc[df['RAZÃO SOCIAL'] == empresa, 'Data 04'].values[0]
        novo_df.at[index, 'data_inicial'] = data_oficial4
        
for index, row in df1_fase5.iterrows():
    empresa = row['RAZÃO SOCIAL']
    if empresa in df['RAZÃO SOCIAL'].values:
        data_oficial5 = df.loc[df['RAZÃO SOCIAL'] == empresa, 'Data 05'].values[0]
        novo_df.at[index, 'data_inicial'] = data_oficial5

for index, row in df1_fase6.iterrows():
    empresa = row['RAZÃO SOCIAL']
    if empresa in df['RAZÃO SOCIAL'].values:
        data_oficial6 = df.loc[df['RAZÃO SOCIAL'] == empresa, 'Data 06'].values[0]
        novo_df.at[index, 'data_inicial'] = data_oficial6

for index, row in df1_fase7.iterrows():
    empresa = row['RAZÃO SOCIAL']
    if empresa in df['RAZÃO SOCIAL'].values:
        data_oficial7 = df.loc[df['RAZÃO SOCIAL'] == empresa, 'Data 07'].values[0]
        novo_df.at[index, 'data_inicial'] = data_oficial7
for index, row in df1_fase8.iterrows():
    empresa = row['RAZÃO SOCIAL']
    if empresa in df['RAZÃO SOCIAL'].values:
        data_oficial8 = df.loc[df['RAZÃO SOCIAL'] == empresa, 'Data 08'].values[0]
        novo_df.at[index, 'data_inicial'] = data_oficial8
        
for index, row in df1_fase9.iterrows():
    empresa = row['RAZÃO SOCIAL']
    if empresa in df['RAZÃO SOCIAL'].values:
        data_oficial9 = df.loc[df['RAZÃO SOCIAL'] == empresa, 'Data 09'].values[0]
        novo_df.at[index, 'data_inicial'] = data_oficial9
        
# Exibir o dataframe novo_df com as informações atualizadas

# %%
#data final 
# Filtrar df1 para as linhas em que etapas é igual a "fase 1"
df1_fase1 = novo_df[novo_df['Etapa'] == 'Etapa 1']
df1_fase2 = novo_df[novo_df['Etapa'] == 'Etapa 2']
df1_fase3 = novo_df[novo_df['Etapa'] == 'Etapa 3']
df1_fase4 = novo_df[novo_df['Etapa'] == 'Etapa 4']
df1_fase5 = novo_df[novo_df['Etapa'] == 'Etapa 5']
df1_fase6 = novo_df[novo_df['Etapa'] == 'Etapa 6']
df1_fase7 = novo_df[novo_df['Etapa'] == 'Etapa 7']
df1_fase8 = novo_df[novo_df['Etapa'] == 'Etapa 8']
df1_fase9 = novo_df[novo_df['Etapa'] == 'Etapa 9']

# Criar uma nova coluna 'data_inicial' em novo_df
novo_df['data_final'] = None

# Preencher a coluna 'data_inicial' em novo_df com as informações correspondentes em df2
for index, row in df1_fase1.iterrows():
    empresa = row['RAZÃO SOCIAL']
    if empresa in df['RAZÃO SOCIAL'].values:
        data_oficial = df.loc[df['RAZÃO SOCIAL'] == empresa, 'Data 02'].values[0]
        novo_df.at[index, 'data_final'] = data_oficial

for index, row in df1_fase2.iterrows():
    empresa = row['RAZÃO SOCIAL']
    if empresa in df['RAZÃO SOCIAL'].values:
        data_oficial2 = df.loc[df['RAZÃO SOCIAL'] == empresa, 'Data 03'].values[0]
        novo_df.at[index, 'data_final'] = data_oficial2
        
for index, row in df1_fase3.iterrows():
    empresa = row['RAZÃO SOCIAL']
    if empresa in df['RAZÃO SOCIAL'].values:
        data_oficial3 = df.loc[df['RAZÃO SOCIAL'] == empresa, 'Data 04'].values[0]
        novo_df.at[index, 'data_final'] = data_oficial3
        
for index, row in df1_fase4.iterrows():
    empresa = row['RAZÃO SOCIAL']
    if empresa in df['RAZÃO SOCIAL'].values:
        data_oficial4 = df.loc[df['RAZÃO SOCIAL'] == empresa, 'Data 05'].values[0]
        novo_df.at[index, 'data_final'] = data_oficial4
        
for index, row in df1_fase5.iterrows():
    empresa = row['RAZÃO SOCIAL']
    if empresa in df['RAZÃO SOCIAL'].values:
        data_oficial5 = df.loc[df['RAZÃO SOCIAL'] == empresa, 'Data 06'].values[0]
        novo_df.at[index, 'data_final'] = data_oficial5

for index, row in df1_fase6.iterrows():
    empresa = row['RAZÃO SOCIAL']
    if empresa in df['RAZÃO SOCIAL'].values:
        data_oficial6 = df.loc[df['RAZÃO SOCIAL'] == empresa, 'Data 07'].values[0]
        novo_df.at[index, 'data_final'] = data_oficial6

for index, row in df1_fase7.iterrows():
    empresa = row['RAZÃO SOCIAL']
    if empresa in df['RAZÃO SOCIAL'].values:
        data_oficial7 = df.loc[df['RAZÃO SOCIAL'] == empresa, 'Data 08'].values[0]
        novo_df.at[index, 'data_final'] = data_oficial7
        
for index, row in df1_fase8.iterrows():
    empresa = row['RAZÃO SOCIAL']
    if empresa in df['RAZÃO SOCIAL'].values:
        data_oficial8 = df.loc[df['RAZÃO SOCIAL'] == empresa, 'Data 09'].values[0]
        novo_df.at[index, 'data_final'] = data_oficial8
        
for index, row in df1_fase9.iterrows():
    empresa = row['RAZÃO SOCIAL']
    if empresa in df['RAZÃO SOCIAL'].values:
        data_oficial9 = df.loc[df['RAZÃO SOCIAL'] == empresa, 'Data 10'].values[0]
        novo_df.at[index, 'data_final'] = data_oficial9
        
# Exibir o dataframe novo_df com as informações atualizadas

# %%
novo_df['data_inicial'] = pd.to_datetime(novo_df['data_inicial'], errors='coerce')
novo_df['data_final'] = pd.to_datetime(novo_df['data_final'], errors='coerce')
novo_df['Prazo'] = (novo_df['data_final'] - novo_df['data_inicial']).dt.days


novo_df['data_inicial'] = novo_df['data_inicial'].astype('O')
novo_df['data_final'] = novo_df['data_final'].astype('O')
novo_df
# Out:
#    RAZÃO SOCIAL    Etapa         data_inicial           data_final  Prazo
# 0     Empresa A  Etapa 1  2000-10-01 00:00:00  2000-12-01 00:00:00     61
# 1     Empresa A  Etapa 2  2000-12-01 00:00:00  2001-01-01 00:00:00     31
# 2     Empresa A  Etapa 3  2001-01-01 00:00:00  2001-04-01 00:00:00     90
# 3     Empresa A  Etapa 4  2001-04-01 00:00:00  2001-05-01 00:00:00     30
# 4     Empresa A  Etapa 5  2001-05-01 00:00:00  2001-08-01 00:00:00     92
# ..          ...      ...                  ...                  ...    ...
# 94    Empresa K  Etapa 5  2001-05-11 00:00:00  2001-08-11 00:00:00     92
# 95    Empresa K  Etapa 6  2001-08-11 00:00:00  2001-09-11 00:00:00     31
# 96    Empresa K  Etapa 7  2001-09-11 00:00:00  2001-11-11 00:00:00     61
# 97    Empresa K  Etapa 8  2001-11-11 00:00:00  2001-12-11 00:00:00     30
# 98    Empresa K  Etapa 9  2001-12-11 00:00:00  2002-03-11 00:00:00     90
#
# [99 rows x 5 columns]
